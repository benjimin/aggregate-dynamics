# %%
import aggregate
import precompute
import matplotlib.pyplot as plt
import numpy as np

# %%
dates, obsdata = precompute.cell_input(15, -40, window=((0,2000),(0,2000)), limit=200)

# %%
plt.imshow(obsdata.mean(axis=0))

# %%
chunk = obsdata[:,600:700, 700:800]
plt.imshow(chunk.mean(axis=0))

# %%
a,b,c = aggregate.aggregate_wofs(chunk, dates, conservative=False)
[plt.plot(aggregate.defaultdates, i) for i in (a,b,c)]
a
# Out:
# array([265., 265., 265., ..., 265., 265., 265.], dtype=float32)

# %%
a,b,c = aggregate.aggregate_wofs(chunk, dates, conservative=True)
[plt.plot(aggregate.defaultdates, i) for i in (a,b,c)]
# Out:
# [[<matplotlib.lines.Line2D at 0x7f4ecfde2710>],
# ...

# %%
# %time aggregate.aggregate_wofs(chunk, dates)
# Out:
# CPU times: user 4.08 s, sys: 1.36 s, total: 5.44 s
# Wall time: 5.44 s
# (array([265., 265., 265., ..., 265., 265., 265.], dtype=float32),
#  array([3222., 3222., 3222., ..., 3162., 3162., 3162.], dtype=float32),
#  array([3327., 3327., 3327., ..., 3327., 3327., 3327.], dtype=float32))

# %%
chunk.shape, a.shape
# Out:
# ((200, 100, 100), (12419,))

# %%
600*(100**2) / (13000*3)
# Out:
# 153.84615384615384
